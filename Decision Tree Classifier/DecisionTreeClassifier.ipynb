# %%
from sklearn.datasets import load_iris
from sklearn import tree
import pandas as pd
X, y = load_iris(return_X_y=True)
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

# %%
iris =load_iris()

# %%
tree.plot_tree(clf);

# %%
import graphviz

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                      feature_names=iris.feature_names,  
                      class_names=iris.target_names,  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)  
graph

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('Overall Accuracy = %',clf.score(X_test, y_test)*100)
# Out:
# Overall Accuracy = % 93.33333333333333

# %% [markdown]
# ## Prediction on our own samples

# %%
import pandas as pd
import numpy as np
new_data = pd.DataFrame(np.array([ [1,2,3,4],[3,2,6,8],[1.7,4,2,2],[6,3,1,8],[5,6,2,4],
                      [4,2,1,4],[1,2,3,8],[6.7,8,2.4,2],[4,3,1,8],[4,3,2,4],
                      [2,2,4,4],[6,2,2,8],[3.7,4,5,2],[7,3,1,8],[2,3,2,4],
                      [1,1,1,4],[5,1,2,8],[5.7,4,2,2],[2,3,1,8],[8,6,8,0.3] ]),
                       columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

# %%
new_data
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0             1.0           2.0            3.0           4.0
# 1             3.0           2.0            6.0           8.0
# 2             1.7           4.0            2.0           2.0
# 3             6.0           3.0            1.0           8.0
# 4             5.0           6.0            2.0           4.0
# 5             4.0           2.0            1.0           4.0
# 6             1.0           2.0            3.0           8.0
# 7             6.7           8.0            2.4           2.0
# 8             4.0           3.0            1.0           8.0
# 9             4.0           3.0            2.0           4.0
# 10            2.0           2.0            4.0           4.0
# 11            6.0           2.0            2.0           8.0
# 12            3.7           4.0            5.0           2.0
# 13            7.0           3.0            1.0           8.0
# ...

# %%
pred_labels = clf.predict(new_data)
pred_labels
# Out:
# array([1, 2, 1, 2, 1, 1, 1, 2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 1, 1, 0])

# %%
w = pd.DataFrame(pred_labels,columns=['Species'])
w
# Out:
#     Species
# 0         1
# 1         2
# 2         1
# 3         2
# 4         1
# 5         1
# 6         1
# 7         2
# 8         1
# 9         1
# 10        1
# 11        2
# 12        2
# 13        2
# 14        1
# 15        1
# 16        1
# 17        1
# 18        1
# 19        0

# %%
output = pd.concat([new_data,w],axis=1)
output
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0             1.0           2.0            3.0           4.0        1
# 1             3.0           2.0            6.0           8.0        2
# 2             1.7           4.0            2.0           2.0        1
# 3             6.0           3.0            1.0           8.0        2
# 4             5.0           6.0            2.0           4.0        1
# 5             4.0           2.0            1.0           4.0        1
# 6             1.0           2.0            3.0           8.0        1
# 7             6.7           8.0            2.4           2.0        2
# 8             4.0           3.0            1.0           8.0        1
# 9             4.0           3.0            2.0           4.0        1
# 10            2.0           2.0            4.0           4.0        1
# 11            6.0           2.0            2.0           8.0        2
# ...

# %%
output['Species'] = output['Species'].replace(0,'setora')
output['Species'] = output['Species'].replace(1,'versicolor')
output['Species'] = output['Species'].replace(2,'virginica')

# %%
output
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm     Species
# 0             1.0           2.0            3.0           4.0  versicolor
# 1             3.0           2.0            6.0           8.0   virginica
# 2             1.7           4.0            2.0           2.0  versicolor
# 3             6.0           3.0            1.0           8.0   virginica
# 4             5.0           6.0            2.0           4.0  versicolor
# 5             4.0           2.0            1.0           4.0  versicolor
# 6             1.0           2.0            3.0           8.0  versicolor
# 7             6.7           8.0            2.4           2.0   virginica
# 8             4.0           3.0            1.0           8.0  versicolor
# 9             4.0           3.0            2.0           4.0  versicolor
# 10            2.0           2.0            4.0           4.0  versicolor
# 11            6.0           2.0            2.0           8.0   virginica
# ...
